# %% [markdown]
# ## Disciplina Machine Learning
# ### Aula Prática 03 - Aprendizagem Supervisionada - Parte I
# ### Yuki Miura

# %% [markdown]
# ### PREPARAÇÃO DOS DADOS
#
# Obter a base de dados com a qual irá trabalhar deve passar por, pelo menos, 3 etapas:
#
# 1 - formatação/padronização
#
# 2 - ajustes/correção dos dados
#
# 3 - seleção dos dados

# %%
import pandas as pd

linhas_onibus = pd.read_json("2017_02_13_linhas.json")
linhas_onibus.head(10)
# Out:
#    COD                     NOME SOMENTE_CARTAO CATEGORIA_SERVICO NOME_COR
# 0  464  A. MUNHOZ / J. BOTANICO              S      CONVENCIONAL  AMARELA
# 1  226                   ABAETE              N       ALIMENTADOR  LARANJA
# 2  182                ABRANCHES              N           TRONCAL  AMARELA
# 3  332                 ACROPOLE              N       ALIMENTADOR  LARANJA
# 4  208                AEROPORTO              N      LINHA DIRETA    PRATA
# 5  334                 AGRICOLA              N       ALIMENTADOR  LARANJA
# 6  265        AHU / LOS ANGELES              S      CONVENCIONAL  AMARELA
# 7  560             ALFERES POLI              S      CONVENCIONAL  AMARELA
# 8  232                  ALIANCA              N       ALIMENTADOR  LARANJA
# 9  629           ALTO BOQUEIR?O              N       ALIMENTADOR  LARANJA

# %% [markdown]
# #### Contabilizando as linhas de ônibus por cor e pela categoria de serviço

# %%
# Conta a quantidade de cores diferentes nos dados
cor_count = linhas_onibus['NOME_COR'].value_counts()
cor_count.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Conta a quantidade de categorias de serviço
categ_count = linhas_onibus['CATEGORIA_SERVICO'].value_counts()
categ_count.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Python também pode ser utilizados para lidar com dados em json

# %%
# Verificar se algum dado está ausente
print(str(linhas_onibus.describe()))
# Out:
#         COD                     NOME SOMENTE_CARTAO CATEGORIA_SERVICO NOME_COR
# count   301                      301            301               301      301
# unique  301                      301              3                10        9
# top     464  A. MUNHOZ / J. BOTANICO              N       ALIMENTADOR  LARANJA
# freq      1                        1            218               140      140

# %%
linhas_onibus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COD                301 non-null    object
#  1   NOME               301 non-null    object
#  2   SOMENTE_CARTAO     301 non-null    object
#  3   CATEGORIA_SERVICO  301 non-null    object
#  4   NOME_COR           301 non-null    object
# dtypes: object(5)
# memory usage: 11.9+ KB

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
carros = pd.read_csv("carros.csv")
carros.head(10)
# Out:
# <style>.container { width:100% !important; }</style>
#    Unnamed: 0 fabricante      modelo   ano       combustivel     hp  \
# 0           0        BMW  1 Series M  2011  gasolina premium  335.0
# 1           1        BMW    1 Series  2011  gasolina premium  300.0
# 2           2        BMW    1 Series  2011  gasolina premium  300.0
# 3           3        BMW    1 Series  2011  gasolina premium  230.0
# 4           4        BMW    1 Series  2011  gasolina premium  230.0
# 5           5        BMW    1 Series  2012  gasolina premium  230.0
# 6           6        BMW    1 Series  2012  gasolina premium  300.0
# 7           7        BMW    1 Series  2012  gasolina premium  300.0
# 8           8        BMW    1 Series  2012  gasolina premium  230.0
# 9           9        BMW    1 Series  2013  gasolina premium  230.0
#
#    cilindros tipo_transmissao           tracao  num_portas  \
# 0        6.0           MANUAL  tracao_traseira         2.0
# 1        6.0           MANUAL  tracao_traseira         2.0
# 2        6.0           MANUAL  tracao_traseira         2.0
# 3        6.0           MANUAL  tracao_traseira         2.0
# 4        6.0           MANUAL  tracao_traseira         2.0
# 5        6.0           MANUAL  tracao_traseira         2.0
# 6        6.0           MANUAL  tracao_traseira         2.0
# 7        6.0           MANUAL  tracao_traseira         2.0
# 8        6.0           MANUAL  tracao_traseira         2.0
# 9        6.0           MANUAL  tracao_traseira         2.0
#
#                                 categoria   tamanho       estilo  \
# 0  Audio de Fabrica,Luxo,Alta-Performance  compacto         Cupê
# 1                        Luxo,Performance  compacto  Conversível
# 2                   Luxo,Alta-Performance  compacto         Cupê
# 3                        Luxo,Performance  compacto         Cupê
# 4                                    Luxo  compacto  Conversível
# 5                        Luxo,Performance  compacto         Cupê
# 6                        Luxo,Performance  compacto  Conversível
# 7                   Luxo,Alta-Performance  compacto         Cupê
# 8                                    Luxo  compacto  Conversível
# 9                                    Luxo  compacto  Conversível
#
#    km_por_l_estrada  km_por_l_cidade  popularidade  preco_venda  \
# 0                26               19          3916        46135
# 1                28               19          3916        40650
# 2                28               20          3916        36350
# 3                28               18          3916        29450
# 4                28               18          3916        34500
# 5                28               18          3916        31200
# 6                26               17          3916        44100
# 7                28               20          3916        39300
# 8                28               18          3916        36900
# 9                27               18          3916        37200
#
#             label
# 0  BMW 1 Series M
# 1    BMW 1 Series
# 2    BMW 1 Series
# 3    BMW 1 Series
# 4    BMW 1 Series
# 5    BMW 1 Series
# 6    BMW 1 Series
# 7    BMW 1 Series
# 8    BMW 1 Series
# 9    BMW 1 Series

# %%
carros.shape
# Out:
# (11914, 18)

# %%
# Ajuste dos nomes das colunas do dataframe
#carros = carros.iloc[:, 1:]
#carros.shape
# Out:
# (11914, 17)

# %%
carros.columns = ['fabricante', 'modelo', 'ano', 'combustivel', 'hp',
                  'cilindros', 'tipo_transmissao', 'tracao', 'num_portas',
                  'categoria', 'tamanho', 'estilo', 'km_por_l_estrada',
                  'km_por_l_cidade', 'popularidade', 'preco_venda', 'label']

#carros.head(10)

# %%
# Preenche os dados faltantes
carros['categoria'].fillna('INDEFINIDO', inplace=True)
carros['combustivel'].fillna('alcool', inplace=True)
carros['num_portas'].fillna(2., inplace=True)

# Cria a coluna com os labels (fabrincate + modelo)
#carros['label'] = carros['fabricante'] + ' ' + carros['modelo']

# Converte as colunas para categorias
carros ['combustivel'] = carros ['combustivel'].astype('category')
carros ['tipo_transmissao'] = carros ['tipo_transmissao'].astype('category')
carros ['tracao'] = carros ['tracao'].astype('category')
carros ['categoria'] = carros ['categoria'].astype('category')
carros ['tamanho'] = carros ['tamanho'].astype('category')
carros ['estilo'] = carros ['estilo'].astype('category')
carros ['label'] = carros ['label'].astype('category')

# %%
# Substitui os valores das colunas categoricas pelos valores numericos
cat_columns = carros.select_dtypes(['category']).columns
carros[cat_columns] = carros[cat_columns].apply(lambda x: x.cat.codes)
#carros.head()

#carros ['label'] = carros ['label'].astype('category')
#carros['label'] = carros['label'].cat.codes
#carros.to_csv("carros.csv")

carros.loc[:, 'ano':].head()
# Out:
#     ano  combustivel     hp  cilindros  tipo_transmissao  tracao  num_portas  \
# 0  2011            7  335.0        6.0                 3       3         2.0
# 1  2011            7  300.0        6.0                 3       3         2.0
# 2  2011            7  300.0        6.0                 3       3         2.0
# 3  2011            7  230.0        6.0                 3       3         2.0
# 4  2011            7  230.0        6.0                 3       3         2.0
#
#    categoria  tamanho  estilo  km_por_l_estrada  km_por_l_cidade  \
# 0          3        0       5                26               19
# 1         68        0       4                28               19
# 2         65        0       5                28               20
# 3         68        0       5                28               18
# 4         64        0       4                28               18
#
#    popularidade  preco_venda  label
# 0          3916        46135     66
# 1          3916        40650     65
# 2          3916        36350     65
# 3          3916        29450     65
# 4          3916        34500     65

# %%
carros.to_csv("carros_categorical.csv", index=False)

# %% [markdown]
# ### Preparação, Separação dos Dados e Treinamento de uma DT

# %%
# Exemplo didatico de uma arvore

df_clientes = pd.read_csv("dados_clientes_nome.csv")
df_clientes
# Out:
#      nome  idade  nacionalidade  altura  peso  sexo  gosta de futebol  salario
# 0    Aldo     22              0    1.70    75     0                 1     2500
# 1    Beto     52              1    1.75    80     0                 1     2500
# 2     Bia     31              1    1.50    65     1                 1     4500
# 3  Carlos     65              1    1.95    86     0                 0     6500
# 4   Diego     17              0    1.81    95     0                 1     1500
# 5   Daina     54              0    1.65    80     1                 0     3500
# 6   Carol     30              0    1.90   105     1                 1     1200
# 7   Fabia     25              1    1.85    65     1                 1     2245
# 8   Felix     49              0    1.71    75     0                 0    25000
# 9    Gaia     26              1    1.81    80     1                 1     8000

# %%
#!pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.17

# %%
# Treina um algoritmo de árvore de decisão com os dados
from sklearn import tree

atributos = ['idade', 'nacionalidade', 'altura', 'peso', 'sexo', 'salario']

X_treino = df_clientes.loc[:, atributos].to_numpy()
y_treino = df_clientes['gosta de futebol'].to_numpy()

clf = tree.DecisionTreeClassifier(criterion = "gini", splitter = "best",
                                  max_depth = 10,  min_samples_split = 5,
                                  min_samples_leaf = 1, max_features = 6)
clf = clf.fit(X_treino, y_treino)

import graphviz
categorias_gosta_futebol = ['não gosta futebol','gosta futebol']
dot_data = tree.export_graphviz(clf, out_file=None, filled=True,
                                rounded=True,
                                special_characters=True,
                                feature_names = atributos,
                                class_names=categorias_gosta_futebol)
graph = graphviz.Source(dot_data)
graph.render("futebol_tree")
# Out:
# 'futebol_tree.pdf'

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
import matplotlib.pyplot as plt

cv_results = cross_val_predict(clf, X_treino, y_treino, cv=3)
print(classification_report(y_treino, cv_results, target_names=categorias_gosta_futebol))

fig, ax = plt.subplots()
ax.scatter(y_treino, cv_results, edgecolors=(0, 0, 0))
ax.plot([y_treino.min(), y_treino.max()], [y_treino.min(), y_treino.max()], 'k--', lw=4)
ax.set_xlabel('Real')
ax.set_ylabel('Predição')
plt.show()

# Plota matriz de confusao
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_treino, y_treino,
                                 display_labels=categorias_gosta_futebol,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
plt.show()
# Out:
#                    precision    recall  f1-score   support
#
# não gosta futebol       0.67      0.67      0.67         3
#     gosta futebol       0.86      0.86      0.86         7
#
#          accuracy                           0.80        10
#         macro avg       0.76      0.76      0.76        10
#      weighted avg       0.80      0.80      0.80        10

# %%
# Exemplo didatico de uma arvore

df_clientes = pd.read_csv("dados_clientes_nome.csv")

# Treina um algoritmo de árvore de decisão com os dados
from sklearn import tree

atributos = ['idade', 'altura', 'peso', 'sexo', 'gosta de futebol','salario']

X_treino = df_clientes.loc[:, atributos].to_numpy()
y_treino = df_clientes['nacionalidade'].to_numpy()

clf = tree.DecisionTreeClassifier(criterion = "gini", splitter = "best",
                                  max_depth = 5,  min_samples_split = 5,
                                  min_samples_leaf = 2, max_features = 5)
clf = clf.fit(X_treino, y_treino)

import graphviz
dot_data = tree.export_graphviz(clf, out_file=None, filled=True,
                                rounded=True,
                                special_characters=True,
                                feature_names = atributos,
                                class_names=['estrangeiro','brasileiro'])
graph = graphviz.Source(dot_data)
graph.render("nacionalidade_tree")
# Out:
# 'nacionalidade_tree.pdf'

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import pandas as pd

# Lê o dataset de carros
carros = pd.read_csv("carros_categorical.csv")

carros = carros.iloc[:, 1:]

carros
# Out:
#            modelo   ano  combustivel     hp  cilindros  tipo_transmissao  \
# 0      1 Series M  2011            7  335.0        6.0                 3
# 1        1 Series  2011            7  300.0        6.0                 3
# 2        1 Series  2011            7  300.0        6.0                 3
# 3        1 Series  2011            7  230.0        6.0                 3
# 4        1 Series  2011            7  230.0        6.0                 3
# ...           ...   ...          ...    ...        ...               ...
# 11909         ZDX  2012            7  300.0        6.0                 0
# 11910         ZDX  2012            7  300.0        6.0                 0
# 11911         ZDX  2012            7  300.0        6.0                 0
# 11912         ZDX  2013            5  300.0        6.0                 0
# 11913      Zephyr  2006            6  221.0        6.0                 0
#
#        tracao  num_portas  categoria  tamanho  estilo  km_por_l_estrada  \
# 0           3         2.0          3        0       5                26
# 1           3         2.0         68        0       4                28
# 2           3         2.0         65        0       5                28
# 3           3         2.0         68        0       5                28
# 4           3         2.0         64        0       4                28
# ...       ...         ...        ...      ...     ...               ...
# 11909       1         4.0         19        2       2                23
# 11910       1         4.0         19        2       2                23
# 11911       1         4.0         19        2       2                23
# 11912       1         4.0         19        2       2                23
# 11913       2         4.0         64        2      12                26
#
#        km_por_l_cidade  popularidade  preco_venda  label
# 0                   19          3916        46135     66
# 1                   19          3916        40650     65
# 2                   20          3916        36350     65
# 3                   18          3916        29450     65
# 4                   18          3916        34500     65
# ...                ...           ...          ...    ...
# 11909               16           204        46120     17
# 11910               16           204        56670     17
# 11911               16           204        50620     17
# 11912               16           204        50920     17
# 11913               17            61        28995    566
#
# [11914 rows x 16 columns]

# %%
# Seleciona apenas as colunas necessárias
X = carros.loc[:, 'ano':'preco_venda'].to_numpy()
y = carros['label'].to_numpy()

# %%
len(np.unique(y))
# Out:
# 928

# %%
# Divide o conjunto em treinamento e teste, na proporção 80-20
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.25,
                                                        random_state=123,
                                                        shuffle=True)

caracteristicas = list(carros.columns[2:-1])
carros['fabricante'] = carros ['fabricante'].astype('category')
categorias = carros['fabricante'].cat.categories

print("Tamanho do conjunto de treinamento: {}".format(len(X_treino)))
print("Tamanho do conjunto de testes: {}".format(len(X_teste)))
print("Quantidade de características: {}".format(len(caracteristicas)))
print("Quantidade de classes ou categorias: {}".format(len(carros ['fabricante'].cat.categories)))

# Conta a quantidade de categorias de serviço
categ_count = carros['fabricante'].value_counts()
print(str(categ_count))
# Out:
# Tamanho do conjunto de treinamento: 8935
# Tamanho do conjunto de testes: 2979
# Quantidade de características: 14
# Quantidade de classes ou categorias: 48
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# HUMMER             17
# Maybach            16
# McLaren             5
# Alfa Romeo          5
# Spyker              3
# Bugatti             3
# Genesis             3
# Name: fabricante, dtype: int64

# %%
categ_count.plot.bar()
# Out:
# <AxesSubplot:>

# %%
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fabricante        11914 non-null  category
#  1   modelo            11914 non-null  object
#  2   ano               11914 non-null  int64
#  3   combustivel       11914 non-null  int64
#  4   hp                11914 non-null  float64
#  5   cilindros         11914 non-null  float64
#  6   tipo_transmissao  11914 non-null  int64
#  7   tracao            11914 non-null  int64
#  8   num_portas        11914 non-null  float64
#  9   categoria         11914 non-null  int64
#  10  tamanho           11914 non-null  int64
#  11  estilo            11914 non-null  int64
#  12  km_por_l_estrada  11914 non-null  int64
#  13  km_por_l_cidade   11914 non-null  int64
#  14  popularidade      11914 non-null  int64
#  15  preco_venda       11914 non-null  int64
#  16  label             11914 non-null  int64
# dtypes: category(1), float64(3), int64(12), object(1)
# memory usage: 1.5+ MB

# %%
# Divide o conjunto em 3 folds
#kf = KFold(n_splits=3)
#idx_folds = kf.split(X)

#for idx_treino, idx_teste in idx_folds:
#    X_treino, X_teste = X[idx_treino], X[idx_teste]
#    y_treino, y_teste = y[idx_treino], y[idx_teste]
#    print('idx_treino: {} idx_teste: {}'.format(idx_treino, idx_teste))
# Out:
# Tamanho do conjunto de treinamento: 9531
# Tamanho do conjunto de testes: 2383
# Quantidade de características: 14
# Quantidade de classes ou categorias: 48
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# HUMMER             17
# Maybach            16
# McLaren             5
# Alfa Romeo          5
# Spyker              3
# Bugatti             3
# Genesis             3
# Name: fabricante, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fabricante        11914 non-null  category
#  1   modelo            11914 non-null  object
#  2   ano               11914 non-null  int64
#  3   combustivel       11914 non-null  int64
#  4   hp                11914 non-null  float64
#  5   cilindros         11914 non-null  float64
#  6   tipo_transmissao  11914 non-null  int64
#  7   tracao            11914 non-null  int64
#  8   num_portas        11914 non-null  float64
#  9   categoria         11914 non-null  int64
#  10  tamanho           11914 non-null  int64
#  11  estilo            11914 non-null  int64
#  12  km_por_l_estrada  11914 non-null  int64
#  13  km_por_l_cidade   11914 non-null  int64
#  14  popularidade      11914 non-null  int64
#  15  preco_venda       11914 non-null  int64
#  16  label             11914 non-null  int64
# dtypes: category(1), float64(3), int64(12), object(1)
# memory usage: 1.5+ MB

# %%
# Treina um algoritmo de árvore de decisão com os dados
from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion = "gini", splitter = "best",
                                  max_depth = 3,  min_samples_split = 5,
                                  min_samples_leaf = 2, max_features = 2)

clf_gini_best = clf.fit(X_treino, y_treino)

# %%
# Avalia o desempenho do modelo treinado
import numpy as np
from sklearn.metrics import classification_report

y_pred = clf_gini_best.predict(X_teste)

# %%
categorias = carros['fabricante'].cat.categories
categorias
# Out:
# Index(['Acura', 'Alfa Romeo', 'Aston Martin', 'Audi', 'BMW', 'Bentley',
#        'Bugatti', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge',
#        'FIAT', 'Ferrari', 'Ford', 'GMC', 'Genesis', 'HUMMER', 'Honda',
#        'Hyundai', 'Infiniti', 'Kia', 'Lamborghini', 'Land Rover', 'Lexus',
#        'Lincoln', 'Lotus', 'Maserati', 'Maybach', 'Mazda', 'McLaren',
#        'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth',
#        'Pontiac', 'Porsche', 'Rolls-Royce', 'Saab', 'Scion', 'Spyker',
#        'Subaru', 'Suzuki', 'Tesla', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype='object')

# %%
print("Total de categorias: {}".format(len(categorias)))

cats_teste = np.unique(y_teste).tolist()
cats_teste
code_cats = carros['fabricante'].cat.categories

print(str(code_cats))
print("Total de categorias de teste: {}".format(len(code_cats)))
# Out:
# Total de categorias: 48
# Index(['Acura', 'Alfa Romeo', 'Aston Martin', 'Audi', 'BMW', 'Bentley',
#        'Bugatti', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge',
#        'FIAT', 'Ferrari', 'Ford', 'GMC', 'Genesis', 'HUMMER', 'Honda',
#        'Hyundai', 'Infiniti', 'Kia', 'Lamborghini', 'Land Rover', 'Lexus',
#        'Lincoln', 'Lotus', 'Maserati', 'Maybach', 'Mazda', 'McLaren',
#        'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth',
#        'Pontiac', 'Porsche', 'Rolls-Royce', 'Saab', 'Scion', 'Spyker',
#        'Subaru', 'Suzuki', 'Tesla', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype='object')
# Total de categorias de teste: 48

# %%
# Out:
# 720

# %%
len(np.unique(y_teste))
# Out:
# 768

# %%
resultados = classification_report(y_teste, y_pred,
                                   target_names=code_cats,
                                   output_dict=True)

#print(resultados)

fig, ax = plt.subplots()
ax.scatter(y_teste, y_pred, edgecolors=(0, 0, 0))
ax.plot([y_teste.min(), y_teste.max()], [y_teste.min(), y_teste.max()], 'k--', lw=4)
ax.set_xlabel('Real')
ax.set_ylabel('Predição')
plt.show()

#resultados['FIAT']
# Out:
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-97-eea519c2db99> in <module>
# ----> 1 resultados = classification_report(y_teste, y_pred,
#       2                                    target_names=code_cats,
#       3                                    output_dict=True)
#       4
#       5 #print(resultados)
#
# ~/miniconda3/envs/aulas_uninter_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/aulas_uninter_ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1989             )
#    1990         else:
# -> 1991             raise ValueError(
#    1992                 "Number of classes, {0}, does not match size of "
#    1993                 "target_names, {1}. Try specifying the labels "
#
# ValueError: Number of classes, 768, does not match size of target_names, 48. Try specifying the labels parameter

# %%
# Out:
# 928

# %%
from sklearn.model_selection import cross_val_predict
import matplotlib.pyplot as plt

cv_results = cross_val_predict(clf_gini_best, X, y, cv=3)
print(classification_report(y, cv_results, target_names=code_cats))

fig, ax = plt.subplots()
ax.scatter(y, cv_results, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Real')
ax.set_ylabel('Predição')
plt.show()
# Out:
# /home/willian/miniconda3/envs/aulas_uninter_ml/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(("The least populated class in y has only %d"
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-88-7f34df34acc8> in <module>
#       3
#       4 cv_results = cross_val_predict(clf_gini_best, X, y, cv=3)
# ----> 5 print(classification_report(y, cv_results, target_names=code_cats))
#       6
#       7 fig, ax = plt.subplots()
#
# ~/miniconda3/envs/aulas_uninter_ml/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/aulas_uninter_ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1989             )
#    1990         else:
# -> 1991             raise ValueError(
#    1992                 "Number of classes, {0}, does not match size of "
#    1993                 "target_names, {1}. Try specifying the labels "
#
# ValueError: Number of classes, 928, does not match size of target_names, 48. Try specifying the labels parameter

# %%
# Serializa o modelo treinado
import pickle

# %%
# Exemplo de uso de isolation forest
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
rng = np.random.RandomState(42)

#  Treina o modelo
clf = IsolationForest(max_samples=1000, random_state=rng)
clf.fit(X_treino)
y_pred_train = clf.predict(X_treino)
y_pred_test = clf.predict(X_teste)

plt.title("IsolationForest")

b1 = plt.scatter(X_treino[:, 0], X_treino[:, 1], c='white',
                 s=20, edgecolor='k')
b2 = plt.scatter(X_teste[:, 0], X_teste[:, 1], c='green',
                 s=20, edgecolor='k')
plt.axis('tight')
plt.xlim((-5, 5))
plt.ylim((-5, 5))
plt.legend([b1, b2],
           ["instancias de treino",
            "instancias de teste"],
           loc="upper left")
plt.show()
